# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %% [markdown]
# # Variables

# %%
df = gpd.read_file('join.json')
df = df.set_geometry('geometry')
df = df.set_index('idParcela')
df
# Out:
#                    par_idparcela                           id  \
# idParcela
# 2519551-SAN ROQUE        2519551   parcelas.1968815804.503484
# 2449020-SANTIAGO         2449020  parcelas.1134491604.1492639
# 2448933-SAN ROQUE        2448933   parcelas.1134483604.595151
# 1205390-SANTIAGO         1205390    parcelas.378770638.725360
# 1141971-SAN ROQUE        1141971      parcelas.4486739.890158
# ...                          ...                          ...
# 1204495-SAN ROQUE        1204495     parcelas.4540744.1280373
# 1136506-SAN ROQUE        1136506    parcelas.359555602.380299
# 1173094-SAN ROQUE        1173094    parcelas.151115602.121389
# 1181494-SAN ROQUE        1181494  parcelas.1114448451.1279833
# 1199878-SANTIAGO         1199878    parcelas.13185845.1808648
#
#                        Nomenclatura Tipo_Parcela Tipo_Valuacion  \
# idParcela
# 2519551-SAN ROQUE  2304694302023118       URBANO    VAL. URBANO
# 2449020-SANTIAGO   2304553803282033       URBANO    VAL. URBANO
# 2448933-SAN ROQUE  2304553803277037       URBANO    VAL. URBANO
# 1205390-SANTIAGO   2305604702047012       URBANO    VAL. URBANO
# 1141971-SAN ROQUE  2304463102010010       URBANO    VAL. URBANO
# ...                             ...          ...            ...
# 1204495-SAN ROQUE  2305604701165003       URBANO    VAL. URBANO
# 1136506-SAN ROQUE  2304154302001008       URBANO    VAL. URBANO
# 1173094-SAN ROQUE  2304553803048007       URBANO    VAL. URBANO
# 1181494-SAN ROQUE  2304554001009001       URBANO    VAL. URBANO
# 1199878-SANTIAGO   2305517238350456        RURAL     VAL. RURAL
#
#                            Estado         desig_oficial      exp_creacion  \
# idParcela
# 2519551-SAN ROQUE          BALDIO  LT. 118 - MZ. OF. 23  0033-129291/2022
# 2449020-SANTIAGO           BALDIO          MZ 282 LT 33  0033-087801/2014
# 2448933-SAN ROQUE          BALDIO          MZ 277 LT 37  0033-087801/2014
# 1205390-SANTIAGO   EDIFICADO NoPH           MZ 47 LT 12  0033-034424/2000
# 1141971-SAN ROQUE          BALDIO               032 018
# ...                           ...                   ...               ...
# 1204495-SAN ROQUE          BALDIO           MZ 165 LT 3  0033-053341/1995
# 1136506-SAN ROQUE  EDIFICADO NoPH     MANZANA 6 LOTE 36          -      /
# 1173094-SAN ROQUE  EDIFICADO NoPH      MZ 8 LT 7 4A SEC
# 1181494-SAN ROQUE  EDIFICADO NoPH            MZ 7-LT 14       00000336715
# 1199878-SANTIAGO           BALDIO           SAN ANTONIO       03050105429
#
#                   Fecha_Creacion fecha_alta_parcela  ...       dnbrurb  \
# idParcela                                            ...
# 2519551-SAN ROQUE        01-2023            08-2022  ... -1.585549e+09
# 2449020-SANTIAGO         01-2020            11-2019  ...  1.537357e+09
# 2448933-SAN ROQUE        01-2020            11-2019  ...  4.129563e+09
# 1205390-SANTIAGO         01-2000            03-2007  ...  3.036931e+08
# 1141971-SAN ROQUE        01-1901            03-2007  ...  1.645820e+08
# ...                          ...                ...  ...           ...
# 1204495-SAN ROQUE        01-2000            03-2007  ... -8.210127e+08
# 1136506-SAN ROQUE        01-1901            03-2007  ... -7.812374e+08
# 1173094-SAN ROQUE        01-1901            03-2007  ... -1.213963e+08
# 1181494-SAN ROQUE        01-1901            03-2007  ...  2.153465e+09
# 1199878-SANTIAGO         01-1901            03-2007  ... -0.000000e+00
#
#                          valmej        mejurb      mejrur        mejsup  \
# idParcela
# 2519551-SAN ROQUE  0.000000e+00      0.000000    0.000000      0.000000
# 2449020-SANTIAGO   0.000000e+00      0.000000    0.000000      0.000000
# 2448933-SAN ROQUE  0.000000e+00      0.000000    0.000000      0.000000
# 1205390-SANTIAGO   2.291372e+08   2950.517847    0.000000   2954.702979
# 1141971-SAN ROQUE  0.000000e+00      0.000000    0.000000      0.000000
# ...                         ...           ...         ...           ...
# 1204495-SAN ROQUE  0.000000e+00      0.000000    0.000000      0.000000
# 1136506-SAN ROQUE  4.069027e+08   2526.451343    0.000000   2529.105179
# 1173094-SAN ROQUE  4.235582e+07   1145.309091    0.000000   1147.854222
# 1181494-SAN ROQUE  4.895712e+09  12022.897547    0.000000  12043.275339
# 1199878-SANTIAGO   0.000000e+00      0.000000  132.550073      0.000000
#
#                          recmej    reclamosup  daniossup  daniossuprec  \
# idParcela
# 2519551-SAN ROQUE  0.000000e+00   8218.421814        NaN           NaN
# 2449020-SANTIAGO   0.000000e+00   5808.940232        NaN           NaN
# 2448933-SAN ROQUE  0.000000e+00  16789.530635        NaN           NaN
# 1205390-SANTIAGO   6.957131e+11  52584.904397        NaN           NaN
# 1141971-SAN ROQUE  0.000000e+00    572.706900        NaN           NaN
# ...                         ...           ...        ...           ...
# 1204495-SAN ROQUE  0.000000e+00  11845.134573        NaN           NaN
# 1136506-SAN ROQUE  7.857485e+11  58276.262763        NaN           NaN
# 1173094-SAN ROQUE  6.673396e+10  23829.406311        NaN           NaN
# 1181494-SAN ROQUE  1.383029e+11  22763.110576        NaN           NaN
# 1199878-SANTIAGO   0.000000e+00   2980.737223        NaN           NaN
#
#                                                             geometry
# idParcela
# 2519551-SAN ROQUE  MULTIPOLYGON (((350955.692 -3482913.519, 35094...
# 2449020-SANTIAGO   MULTIPOLYGON (((355637.248 -3479241.406, 35563...
# 2448933-SAN ROQUE  MULTIPOLYGON (((355476.133 -3478789.507, 35547...
# 1205390-SANTIAGO   MULTIPOLYGON (((352758.919 -3482607.312, 35274...
# 1141971-SAN ROQUE  MULTIPOLYGON (((362283.674 -3467544.086, 36231...
# ...                                                              ...
# 1204495-SAN ROQUE  MULTIPOLYGON (((351295.629 -3482381.63, 351305...
# 1136506-SAN ROQUE  MULTIPOLYGON (((351196.889 -3482705.455, 35119...
# 1173094-SAN ROQUE  MULTIPOLYGON (((355659.33 -3477438.898, 355688...
# 1181494-SAN ROQUE  MULTIPOLYGON (((358134.083 -3477351.122, 35815...
# 1199878-SANTIAGO   MULTIPOLYGON (((350368.141 -3483261.336, 35033...
#
# [1047 rows x 52 columns]

# %%
df.select_dtypes(['number']).corr().abs().sort_values('ValorReclamo', ascending=False)[['ValorReclamo', 'Valuacion_Danios']]
# Out:
#                               ValorReclamo  Valuacion_Danios
# ValorReclamo                      1.000000          0.411769
# recmej                            0.918723          0.537222
# Valuacion                         0.915919          0.371094
# dnbrmej                           0.872739          0.370641
# Valuacion_Mejoras                 0.867460          0.497031
# Superficie_Mejoras                0.866166          0.462481
# mejurb                            0.864667          0.553525
# valmej                            0.860259          0.496482
# daniossup                         0.470843          0.936565
# daniossuprec                      0.455454          0.356932
# Valuacion_Danios                  0.411769          1.000000
# Valuacion_Tierra_Urbana           0.317104          0.461477
# Superficie_Tierra_Urbana          0.316809          0.188565
# dnbrurb                           0.313935          0.028586
# Valuacion_Tierra_Rural            0.265982               NaN
# mejrur                            0.241748               NaN
# fxf                               0.159341          0.112470
# dnbr_promedio                     0.115357          0.067123
# Superficie                        0.111798          0.188565
# dnbrtot                           0.099934          0.033900
# Superficie_Tierra_Rural           0.096886               NaN
# row_number                        0.080709          0.346916
# par_idparcela                     0.071858          0.352022
# reclamosup                        0.057699          0.481817
# Nro_Cuenta                        0.026652          0.583981
# mejsup                            0.012355          0.553592
# porcentaje_copropiedad            0.010340               NaN
# par_entityid                      0.005438          0.375280
# vut_vigente                       0.004126          0.443201
# Cantidad_Cuentas                  0.001538               NaN
# base_imponible_tierra_urbana           NaN               NaN
# base_imponible_tierra_rural            NaN               NaN
# base_imponible_mejoras                 NaN               NaN

# %%
features = [
 'Valuacion',
 'Superficie_Tierra_Urbana',
 'Valuacion_Tierra_Urbana',
 'Superficie_Tierra_Rural',
 'Valuacion_Tierra_Rural',
 'Superficie_Mejoras',
 'Valuacion_Mejoras',
 'dnbr_promedio',
 'Superficie',
 'dnbrtot',
 'dnbrmej',
 'dnbrurb',
 'valmej',
 'mejurb',
 'mejrur',
 'mejsup'
]

# %% [markdown]
# # Datos

# %%
from sklearn import model_selection, impute

# %%
imputer = impute.SimpleImputer()

datos = df.sample(frac=1).reset_index(drop=True) # Permuto las filas al azar x si estaban ordenadas
y = datos['ValorReclamo']
X = imputer.fit_transform(datos.loc[:, features])

y.describe()
# Out:
# count    1.047000e+03
# mean     8.414243e+07
# std      4.918177e+08
# min      7.574885e+04
# 25%      9.731857e+06
# 50%      2.447951e+07
# 75%      5.358665e+07
# max      1.360099e+10
# Name: ValorReclamo, dtype: float64

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y)

# %% [markdown]
# # Modelos

# %%
from sklearn import neighbors, tree, linear_model, ensemble
import matplotlib.pyplot as plt

# %%
tree_params = {'max_depth': np.arange(1, 50, 1), 'criterion': ['absolute_error', 'poisson', 'friedman_mse', 'squared_error'], 'max_features': ['sqrt', 'log2']}
knn_params = {'n_neighbors': np.arange(1, 200, 1), 'metric': ['l1', 'l2', 'cosine']}
svm_params = {'C': np.linspace(1, 10, 100), 'tol': np.logspace(-1, -6, 100), 'kernel': ['linear', 'rbf']}
elastic_params  = {'alpha': np.logspace(-10, 10, 100), 'l1_ratio': np.linspace(0, 1, 100), 'fit_intercept': [False, True]}

forest_params = {
    'n_estimators': np.arange(100, 1000, 100),
    'max_depth': np.arange(1, 50, 1),
    'min_samples_split': np.arange(2, 11, 1),
    'min_samples_leaf': np.arange(1, 11, 1),
    'max_features': ['sqrt', 'log2', None],
    'bootstrap': [True, False]
}
gradient_params = {
    'n_estimators': np.arange(100, 1000, 100),
    'learning_rate': np.logspace(-3, 0, 20),
    'max_depth': np.arange(1, 20, 1),
    'min_samples_split': np.arange(2, 11, 1),
    'min_samples_leaf': np.arange(1, 11, 1),
    'subsample': np.linspace(0.5, 1.0, 6),
    'max_features': ['sqrt', 'log2', None]
}

# %%
modelos = {
    tree.DecisionTreeRegressor: tree_params,
    neighbors.KNeighborsRegressor: knn_params,
    linear_model.ElasticNet: elastic_params,
    ensemble.RandomForestRegressor: forest_params,
    ensemble.GradientBoostingRegressor: gradient_params
    # svm.SVR: svm_params, # Tarda mucho (usar gpu + multithread)
}

results = {}
mejores = []

for modelo, params in modelos.items():
    search = model_selection.RandomizedSearchCV(estimator=modelo(),
                                       param_distributions=params,
                                       scoring='neg_mean_absolute_error',
                                       n_iter=100,
                                       n_jobs=-1,
                                       verbose=3)
    search.fit(X_train, y_train)
    results[modelo] = search.cv_results_
    mejores.append(search.best_estimator_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END criterion=poisson, max_depth=22, max_features=log2;, score=-70236123.739 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=22, max_features=log2;, score=-48902654.662 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=8, max_features=sqrt;, score=-47552071.342 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=22, max_features=log2;, score=-151932179.966 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=8, max_features=sqrt;, score=-37279123.735 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=8, max_features=sqrt;, score=-150763251.532 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=26, max_features=sqrt;, score=-88045585.313 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=42, max_features=log2;, score=-38510620.250 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=26, max_features=sqrt;, score=-36564356.693 total time=   0.0s[CV 2/5] END criterion=poisson, max_depth=26, max_features=sqrt;, score=-33525307.311 total time=   0.0s
#
# [CV 4/5] END criterion=poisson, max_depth=26, max_features=sqrt;, score=-53715394.313 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=26, max_features=sqrt;, score=-165794203.899 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=33, max_features=sqrt;, score=-36082044.870 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=33, max_features=sqrt;, score=-75744234.667 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=22, max_features=log2;, score=-42198534.258 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=33, max_features=sqrt;, score=-41289079.477 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=33, max_features=sqrt;, score=-141939665.749 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=33, max_features=sqrt;, score=-51084858.795 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=28, max_features=log2;, score=-81235687.296 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=28, max_features=log2;, score=-47984481.710 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=28, max_features=log2;, score=-135196621.082 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=22, max_features=log2;, score=-43815330.933 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=28, max_features=log2;, score=-60026417.377 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=14, max_features=log2;, score=-77714444.595 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=28, max_features=log2;, score=-150505938.792 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=14, max_features=log2;, score=-33181661.423 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=14, max_features=log2;, score=-67842952.749 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=14, max_features=log2;, score=-150139544.307 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=14, max_features=log2;, score=-44014555.546 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=40, max_features=sqrt;, score=-77783638.364 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=40, max_features=sqrt;, score=-34267150.501 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=40, max_features=sqrt;, score=-41619182.410 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=40, max_features=sqrt;, score=-81496538.006 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=40, max_features=sqrt;, score=-151631609.658 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=30, max_features=sqrt;, score=-30181881.152 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=30, max_features=sqrt;, score=-79849345.770 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=30, max_features=sqrt;, score=-56056645.875 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=30, max_features=sqrt;, score=-79030776.672 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=43, max_features=log2;, score=-71132211.533 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=30, max_features=sqrt;, score=-175998546.445 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=8, max_features=sqrt;, score=-73487678.912 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=43, max_features=log2;, score=-68469333.926 total time=   0.0s[CV 2/5] END criterion=friedman_mse, max_depth=43, max_features=log2;, score=-54966667.012 total time=   0.0s
#
# [CV 4/5] END criterion=friedman_mse, max_depth=43, max_features=log2;, score=-53733955.079 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=43, max_features=log2;, score=-131452977.757 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=21, max_features=log2;, score=-78083890.323 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=21, max_features=log2;, score=-49531121.489 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=21, max_features=log2;, score=-41285781.137 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=21, max_features=log2;, score=-41011755.884 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=21, max_features=log2;, score=-105439610.383 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=log2;, score=-94263978.685 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=log2;, score=-39601931.243 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=log2;, score=-66900940.772 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=log2;, score=-175837151.488 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=log2;, score=-42518966.592 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=24, max_features=sqrt;, score=-78193799.052 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=24, max_features=sqrt;, score=-46861415.640 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=42, max_features=log2;, score=-40671053.492 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=24, max_features=sqrt;, score=-139139399.937 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=24, max_features=sqrt;, score=-34213130.350 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=16, max_features=sqrt;, score=-40577051.625 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=16, max_features=sqrt;, score=-46018375.109 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=16, max_features=sqrt;, score=-72052599.059 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=24, max_features=sqrt;, score=-43663087.342 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=42, max_features=log2;, score=-83276830.705 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=16, max_features=sqrt;, score=-131242409.505 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=16, max_features=sqrt;, score=-55497930.085 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=26, max_features=sqrt;, score=-80400612.441 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=26, max_features=sqrt;, score=-57452209.455 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=13, max_features=sqrt;, score=-37146233.861 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=26, max_features=sqrt;, score=-141191981.165 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=42, max_features=log2;, score=-46311090.326 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=26, max_features=sqrt;, score=-48609388.413 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=13, max_features=sqrt;, score=-54087005.082 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=26, max_features=sqrt;, score=-41641364.744 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=13, max_features=sqrt;, score=-76844781.562 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=13, max_features=sqrt;, score=-51267654.468 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=38, max_features=sqrt;, score=-53919086.496 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=13, max_features=sqrt;, score=-113825037.066 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=38, max_features=sqrt;, score=-55799423.037 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=38, max_features=sqrt;, score=-36656394.362 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=38, max_features=sqrt;, score=-148909244.601 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=32, max_features=log2;, score=-43745155.652 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=38, max_features=sqrt;, score=-51669804.237 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=32, max_features=log2;, score=-61370716.578 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=32, max_features=log2;, score=-80598864.969 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=23, max_features=sqrt;, score=-55541483.127 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=23, max_features=sqrt;, score=-86319872.448 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=32, max_features=log2;, score=-47741953.308 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=23, max_features=sqrt;, score=-146901866.204 total time=   0.0s[CV 2/5] END criterion=friedman_mse, max_depth=17, max_features=sqrt;, score=-82572215.025 total time=   0.0s
#
# [CV 4/5] END criterion=squared_error, max_depth=23, max_features=sqrt;, score=-46637094.350 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=23, max_features=sqrt;, score=-34523556.872 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=17, max_features=sqrt;, score=-44550884.838 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=17, max_features=sqrt;, score=-55480925.858 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=17, max_features=sqrt;, score=-54961365.742 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=44, max_features=log2;, score=-81655940.359 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=44, max_features=log2;, score=-52895174.971 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=17, max_features=sqrt;, score=-108970025.667 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=32, max_features=log2;, score=-146642761.792 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=44, max_features=log2;, score=-53060211.355 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=44, max_features=log2;, score=-35622568.486 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=44, max_features=log2;, score=-157193362.269 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=17, max_features=sqrt;, score=-38733179.459 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=17, max_features=sqrt;, score=-55759280.483 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=17, max_features=sqrt;, score=-78215293.985 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=21, max_features=sqrt;, score=-57473366.243 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=8, max_features=sqrt;, score=-32948481.446 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=17, max_features=sqrt;, score=-40517348.655 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=17, max_features=sqrt;, score=-151483855.734 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=9, max_features=log2;, score=-83123150.828 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=9, max_features=log2;, score=-144064491.729 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=8, max_features=sqrt;, score=-53506543.020 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=21, max_features=sqrt;, score=-37334470.674 total time=   0.0s[CV 2/5] END criterion=friedman_mse, max_depth=9, max_features=log2;, score=-36065117.746 total time=   0.0s
#
# [CV 1/5] END criterion=friedman_mse, max_depth=21, max_features=sqrt;, score=-83208834.765 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=8, max_features=sqrt;, score=-67912053.567 total time=   0.0s[CV 3/5] END criterion=poisson, max_depth=39, max_features=log2;, score=-37750863.393 total time=   0.0s
#
# [CV 3/5] END criterion=friedman_mse, max_depth=9, max_features=log2;, score=-47928709.020 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=38, max_features=log2;, score=-36692850.671 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=21, max_features=sqrt;, score=-160599108.572 total time=   0.0s[CV 4/5] END criterion=friedman_mse, max_depth=9, max_features=log2;, score=-70150647.144 total time=   0.0s
#
# [CV 1/5] END criterion=poisson, max_depth=37, max_features=log2;, score=-64869159.045 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=21, max_features=sqrt;, score=-35092184.440 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=8, max_features=sqrt;, score=-131584100.721 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=37, max_features=log2;, score=-146104962.759 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=39, max_features=log2;, score=-39390752.455 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=38, max_features=log2;, score=-52803247.521 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=8, max_features=sqrt;, score=-77388791.392 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=37, max_features=log2;, score=-35460733.697 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=25, max_features=sqrt;, score=-60747769.591 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=25, max_features=sqrt;, score=-44164480.039 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=39, max_features=log2;, score=-143970193.757 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=38, max_features=log2;, score=-59246799.641 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=25, max_features=sqrt;, score=-40205252.879 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=25, max_features=sqrt;, score=-150285541.628 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=38, max_features=log2;, score=-78167723.797 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=38, max_features=log2;, score=-145162313.524 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=37, max_features=log2;, score=-50299023.494 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=25, max_features=sqrt;, score=-46842625.950 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=19, max_features=sqrt;, score=-82405891.920 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=40, max_features=sqrt;, score=-32105543.301 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=40, max_features=sqrt;, score=-76291784.483 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=37, max_features=log2;, score=-52704346.906 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=40, max_features=sqrt;, score=-34464348.126 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=40, max_features=sqrt;, score=-36065158.108 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=4, max_features=sqrt;, score=-39173622.272 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=4, max_features=sqrt;, score=-56317887.415 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=40, max_features=sqrt;, score=-153745999.711 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=19, max_features=sqrt;, score=-38785178.881 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=5, max_features=log2;, score=-39748674.681 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=22, max_features=sqrt;, score=-70144972.971 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=4, max_features=sqrt;, score=-58029836.430 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=22, max_features=sqrt;, score=-164149765.801 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=2, max_features=sqrt;, score=-54635193.779 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=5, max_features=log2;, score=-152269701.445 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=4, max_features=sqrt;, score=-83062301.907 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=2, max_features=sqrt;, score=-83098668.559 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=4, max_features=sqrt;, score=-163302254.591 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=5, max_features=log2;, score=-72341163.009 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=2, max_features=sqrt;, score=-73734818.975 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=2, max_features=sqrt;, score=-171808558.731 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=22, max_features=sqrt;, score=-46777337.766 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=2, max_features=sqrt;, score=-37041471.876 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=5, max_features=log2;, score=-41256853.020 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=5, max_features=log2;, score=-45267452.241 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=22, max_features=sqrt;, score=-40448849.840 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=22, max_features=sqrt;, score=-50872956.202 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=19, max_features=sqrt;, score=-36353482.421 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=42, max_features=log2;, score=-140548922.517 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=7, max_features=sqrt;, score=-83800490.991 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=19, max_features=sqrt;, score=-173928039.324 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=36, max_features=log2;, score=-95556850.116 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=26, max_features=log2;, score=-88550346.188 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=7, max_features=sqrt;, score=-42340733.020 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=36, max_features=log2;, score=-127720047.275 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=39, max_features=log2;, score=-55278070.776 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=42, max_features=log2;, score=-49287545.811 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=26, max_features=log2;, score=-143794518.335 total time=   0.0s[CV 1/5] END criterion=squared_error, max_depth=37, max_features=log2;, score=-74895902.712 total time=   0.0s
#
# [CV 2/5] END criterion=poisson, max_depth=39, max_features=log2;, score=-36419629.132 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=27, max_features=log2;, score=-48425159.413 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=36, max_features=log2;, score=-33323072.425 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=37, max_features=log2;, score=-30548958.752 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=37, max_features=log2;, score=-57642131.348 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=36, max_features=log2;, score=-39234672.672 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=19, max_features=sqrt;, score=-53361005.043 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=37, max_features=log2;, score=-42822988.755 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=6, max_features=log2;, score=-35433459.180 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=37, max_features=log2;, score=-151746433.211 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=26, max_features=log2;, score=-31631311.125 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=7, max_features=sqrt;, score=-53355768.393 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=36, max_features=log2;, score=-46436555.119 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=8, max_features=sqrt;, score=-38628882.900 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=42, max_features=log2;, score=-61986643.075 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=42, max_features=log2;, score=-174057054.995 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=27, max_features=log2;, score=-47526092.876 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=45, max_features=sqrt;, score=-48480381.647 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=6, max_features=log2;, score=-53502453.894 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=45, max_features=sqrt;, score=-81479093.867 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=7, max_features=sqrt;, score=-48006350.335 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=26, max_features=log2;, score=-39148620.637 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=27, max_features=log2;, score=-146781281.591 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=6, max_features=log2;, score=-59876647.436 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=45, max_features=sqrt;, score=-44209963.535 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=27, max_features=log2;, score=-73848658.974 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=42, max_features=log2;, score=-30987784.130 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=7, max_features=sqrt;, score=-148370433.824 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=6, max_features=log2;, score=-156690079.763 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=6, max_features=log2;, score=-93049553.148 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=45, max_features=sqrt;, score=-44202023.489 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=26, max_features=log2;, score=-44036123.258 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=45, max_features=sqrt;, score=-156754377.075 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=log2;, score=-90293637.700 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=log2;, score=-44790948.467 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=log2;, score=-57400018.724 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=42, max_features=log2;, score=-59693010.558 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=27, max_features=log2;, score=-43365889.890 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=log2;, score=-35309075.131 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=log2;, score=-150448968.878 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=34, max_features=log2;, score=-54048408.289 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=sqrt;, score=-39601931.243 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=34, max_features=log2;, score=-158347984.740 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=44, max_features=sqrt;, score=-80710190.589 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=sqrt;, score=-42518966.592 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=44, max_features=sqrt;, score=-37963351.049 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=sqrt;, score=-66900940.772 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt;, score=-100528816.538 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=35, max_features=sqrt;, score=-156808534.384 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=21, max_features=sqrt;, score=-38435011.778 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=44, max_features=sqrt;, score=-52840312.286 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt;, score=-51488271.456 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt;, score=-54160490.605 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=6, max_features=sqrt;, score=-49040087.271 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=43, max_features=sqrt;, score=-93300350.762 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=14, max_features=log2;, score=-75496889.880 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt;, score=-81895149.822 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=sqrt;, score=-172372845.175 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=44, max_features=sqrt;, score=-46274132.288 total time=   0.0s[CV 5/5] END criterion=squared_error, max_depth=6, max_features=sqrt;, score=-156937831.100 total time=   0.0s
#
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt;, score=-93674734.823 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=37, max_features=sqrt;, score=-155091018.483 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt;, score=-164993918.134 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt;, score=-35631386.181 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=sqrt;, score=-82385594.657 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=6, max_features=sqrt;, score=-76694341.516 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=35, max_features=sqrt;, score=-79318961.882 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=21, max_features=sqrt;, score=-43175056.484 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt;, score=-60184051.189 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=44, max_features=sqrt;, score=-159785218.531 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=41, max_features=sqrt;, score=-52734359.648 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=40, max_features=sqrt;, score=-80536890.153 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=sqrt;, score=-43144606.623 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=6, max_features=sqrt;, score=-33613863.073 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt;, score=-48873780.379 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt;, score=-58044591.663 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=14, max_features=log2;, score=-34861835.393 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=sqrt;, score=-58217936.340 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=6, max_features=sqrt;, score=-40089796.035 total time=   0.0s[CV 2/5] END criterion=poisson, max_depth=35, max_features=sqrt;, score=-39487197.121 total time=   0.0s
#
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=sqrt;, score=-79712583.028 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=40, max_features=sqrt;, score=-35176969.501 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=sqrt;, score=-94263978.685 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=21, max_features=sqrt;, score=-165142789.611 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt;, score=-132975903.678 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt;, score=-154269085.062 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=41, max_features=sqrt;, score=-66008739.253 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=sqrt;, score=-139638066.434 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=35, max_features=sqrt;, score=-59530562.320 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=9, max_features=sqrt;, score=-78131166.019 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=12, max_features=log2;, score=-33737319.066 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=14, max_features=log2;, score=-32785909.658 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=40, max_features=sqrt;, score=-52092710.686 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=9, max_features=sqrt;, score=-31767105.909 total time=   0.0s[CV 3/5] END criterion=friedman_mse, max_depth=12, max_features=log2;, score=-54934972.643 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=35, max_features=sqrt;, score=-55291900.296 total time=   0.0s
#
# [CV 5/5] END criterion=poisson, max_depth=41, max_features=sqrt;, score=-160177194.987 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt;, score=-84034976.402 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=14, max_features=log2;, score=-49019102.607 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=12, max_features=log2;, score=-39860682.455 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=9, max_features=sqrt;, score=-52830889.416 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=40, max_features=sqrt;, score=-47125703.771 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=31, max_features=log2;, score=-42627709.948 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=12, max_features=log2;, score=-138691167.729 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=9, max_features=sqrt;, score=-47058085.696 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=14, max_features=log2;, score=-160385568.656 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt;, score=-35665459.790 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=log2;, score=-74962319.140 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=19, max_features=log2;, score=-34274129.113 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=43, max_features=sqrt;, score=-35385702.116 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=31, max_features=log2;, score=-41400997.120 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=9, max_features=sqrt;, score=-153285222.411 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=40, max_features=sqrt;, score=-141175921.733 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=log2;, score=-32407499.352 total time=   0.0s[CV 1/5] END criterion=poisson, max_depth=21, max_features=sqrt;, score=-83246309.895 total time=   0.0s
#
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt;, score=-54639105.731 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=31, max_features=log2;, score=-148925075.327 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=16, max_features=sqrt;, score=-71044257.127 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=log2;, score=-35957640.266 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=41, max_features=sqrt;, score=-78749266.685 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=24, max_features=log2;, score=-94707254.026 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=21, max_features=sqrt;, score=-39606338.386 total time=   0.0s[CV 1/5] END criterion=squared_error, max_depth=16, max_features=log2;, score=-75802385.518 total time=   0.0s
#
# [CV 5/5] END criterion=absolute_error, max_depth=18, max_features=sqrt;, score=-145243264.280 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=16, max_features=log2;, score=-34012207.335 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=24, max_features=log2;, score=-44441818.181 total time=   0.0s[CV 2/5] END criterion=poisson, max_depth=41, max_features=sqrt;, score=-45588179.665 total time=   0.0s
#
# [CV 1/5] END criterion=squared_error, max_depth=12, max_features=sqrt;, score=-89396927.582 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=16, max_features=log2;, score=-42557707.660 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=log2;, score=-46953045.014 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=19, max_features=log2;, score=-68630159.499 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=12, max_features=sqrt;, score=-32434330.754 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=24, max_features=log2;, score=-56213411.635 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2;, score=-150997529.224 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=16, max_features=log2;, score=-50885246.309 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=46, max_features=sqrt;, score=-151601679.184 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=43, max_features=sqrt;, score=-55810055.351 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=12, max_features=sqrt;, score=-35764433.834 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=16, max_features=log2;, score=-153830565.985 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=24, max_features=log2;, score=-46798331.842 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=sqrt;, score=-87671663.725 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=12, max_features=sqrt;, score=-48400442.050 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=19, max_features=log2;, score=-51412206.451 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=18, max_features=sqrt;, score=-81984601.429 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=12, max_features=sqrt;, score=-117226246.009 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=sqrt;, score=-28353851.794 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=24, max_features=log2;, score=-171602595.903 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=23, max_features=log2;, score=-109972215.851 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=16, max_features=sqrt;, score=-42416938.185 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=31, max_features=log2;, score=-70075151.566 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=sqrt;, score=-43598747.875 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=sqrt;, score=-59176319.713 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=31, max_features=log2;, score=-66908024.658 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=23, max_features=log2;, score=-53843218.027 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=sqrt;, score=-155192905.505 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=23, max_features=log2;, score=-52677340.286 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=39, max_features=log2;, score=-41789074.421 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=log2;, score=-33421341.019 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=23, max_features=log2;, score=-54403648.531 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=18, max_features=sqrt;, score=-37982979.948 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=23, max_features=log2;, score=-75289813.292 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=43, max_features=sqrt;, score=-41051660.587 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=30, max_features=log2;, score=-46697711.501 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=16, max_features=sqrt;, score=-51488467.189 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=23, max_features=log2;, score=-43053917.721 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=log2;, score=-34039946.991 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=40, max_features=sqrt;, score=-56560838.605 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=19, max_features=log2;, score=-46198358.604 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=23, max_features=log2;, score=-132261442.177 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=23, max_features=log2;, score=-165918636.179 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=log2;, score=-41198153.818 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=6, max_features=log2;, score=-69257889.102 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=40, max_features=sqrt;, score=-67975552.583 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=6, max_features=log2;, score=-51364075.849 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=18, max_features=sqrt;, score=-54009839.075 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=39, max_features=log2;, score=-53128863.825 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=30, max_features=log2;, score=-145158161.138 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=6, max_features=log2;, score=-58425382.647 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=43, max_features=sqrt;, score=-154079267.246 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=log2;, score=-144971213.595 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=6, max_features=log2;, score=-52884979.844 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=34, max_features=log2;, score=-92448326.517 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=6, max_features=log2;, score=-154666998.408 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=23, max_features=log2;, score=-37808123.674 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=34, max_features=log2;, score=-31612316.382 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=16, max_features=sqrt;, score=-55522174.940 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=34, max_features=log2;, score=-32668402.755 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=19, max_features=log2;, score=-144626735.045 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=40, max_features=sqrt;, score=-38133385.822 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=30, max_features=log2;, score=-80263696.344 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=37, max_features=sqrt;, score=-78024533.234 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=18, max_features=sqrt;, score=-38198624.592 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=9, max_features=log2;, score=-53965604.026 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=37, max_features=sqrt;, score=-34750273.001 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=36, max_features=log2;, score=-74358436.252 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=39, max_features=log2;, score=-74807438.067 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=39, max_features=log2;, score=-41650649.729 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=40, max_features=sqrt;, score=-32542145.970 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=37, max_features=sqrt;, score=-36628604.419 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=23, max_features=log2;, score=-57233636.025 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=9, max_features=log2;, score=-33571229.868 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=37, max_features=sqrt;, score=-47779523.613 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=16, max_features=sqrt;, score=-115308327.349 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=12, max_features=log2;, score=-71573821.051 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=9, max_features=log2;, score=-143367240.190 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=9, max_features=log2;, score=-36408357.549 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=36, max_features=log2;, score=-36902920.211 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=40, max_features=sqrt;, score=-154416832.641 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=9, max_features=log2;, score=-48755202.626 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=5, max_features=sqrt;, score=-81764664.625 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=30, max_features=log2;, score=-44793542.175 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=39, max_features=log2;, score=-150138126.197 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=sqrt;, score=-75466380.643 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=5, max_features=sqrt;, score=-54010695.817 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=sqrt;, score=-39706456.954 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=46, max_features=sqrt;, score=-78726966.207 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=sqrt;, score=-50559264.577 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=5, max_features=sqrt;, score=-66025979.934 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=sqrt;, score=-64505198.261 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=5, max_features=sqrt;, score=-36647131.887 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=sqrt;, score=-167199497.745 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=46, max_features=sqrt;, score=-34618376.770 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=5, max_features=sqrt;, score=-144418880.529 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=46, max_features=sqrt;, score=-56924527.739 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=36, max_features=log2;, score=-61572250.282 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=46, max_features=sqrt;, score=-79342308.596 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=21, max_features=log2;, score=-35912722.468 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=21, max_features=log2;, score=-72827075.830 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=21, max_features=log2;, score=-150481217.608 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=41, max_features=sqrt;, score=-72379839.356 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=41, max_features=sqrt;, score=-31616588.212 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=21, max_features=log2;, score=-49591554.547 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=41, max_features=sqrt;, score=-52540927.325 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=21, max_features=log2;, score=-49762404.035 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=41, max_features=sqrt;, score=-54103912.686 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=36, max_features=sqrt;, score=-75572746.628 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=41, max_features=sqrt;, score=-158084300.419 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=26, max_features=log2;, score=-38164383.590 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=26, max_features=log2;, score=-34362184.246 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=26, max_features=log2;, score=-85613367.753 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=36, max_features=sqrt;, score=-34871053.873 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=30, max_features=log2;, score=-42140683.552 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=26, max_features=log2;, score=-60649433.943 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=26, max_features=log2;, score=-154412239.664 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=36, max_features=sqrt;, score=-44446952.427 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=20, max_features=sqrt;, score=-88358031.927 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=36, max_features=sqrt;, score=-53733143.103 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=20, max_features=sqrt;, score=-41535509.749 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=36, max_features=sqrt;, score=-154188495.352 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=36, max_features=log2;, score=-44040413.622 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=20, max_features=sqrt;, score=-49977497.218 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=20, max_features=sqrt;, score=-45006132.337 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=20, max_features=sqrt;, score=-147245266.260 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=9, max_features=sqrt;, score=-69016363.654 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=9, max_features=sqrt;, score=-42023747.529 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=9, max_features=sqrt;, score=-43035882.765 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=9, max_features=sqrt;, score=-57470667.505 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=9, max_features=sqrt;, score=-120136653.833 total time=   0.0s
# ...
# [CV 2/5] END learning_rate=0.004281332398719396, max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=600, subsample=0.8;, score=-30833439.738 total time=   4.5s
# [CV 1/5] END learning_rate=0.004281332398719396, max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=600, subsample=0.8;, score=-66994086.810 total time=   4.8s
# [CV 3/5] END learning_rate=0.6951927961775606, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500, subsample=0.7;, score=-67202506.850 total time=   0.7s
# [CV 5/5] END learning_rate=0.6951927961775606, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500, subsample=0.7;, score=-137762275.257 total time=   0.7s
# [CV 5/5] END learning_rate=0.004281332398719396, max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=600, subsample=0.8;, score=-131092402.809 total time=   4.5s
# [CV 4/5] END learning_rate=0.6951927961775606, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500, subsample=0.7;, score=-74646497.992 total time=   0.8s
# [CV 1/5] END learning_rate=0.6951927961775606, max_depth=12, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=200, subsample=0.8;, score=-131894267.280 total time=   0.6s
# [CV 3/5] END learning_rate=0.6951927961775606, max_depth=12, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=200, subsample=0.8;, score=-78693361.423 total time=   0.4s
# [CV 2/5] END learning_rate=0.6951927961775606, max_depth=12, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=200, subsample=0.8;, score=-60902402.525 total time=   0.5s
# [CV 5/5] END learning_rate=0.6951927961775606, max_depth=12, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=200, subsample=0.8;, score=-142851439.156 total time=   0.5s
# [CV 4/5] END learning_rate=0.6951927961775606, max_depth=12, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=200, subsample=0.8;, score=-128627477.152 total time=   0.5s
# [CV 4/5] END learning_rate=0.004281332398719396, max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=600, subsample=0.8;, score=-35653617.674 total time=   5.1s
# [CV 1/5] END learning_rate=0.018329807108324356, max_depth=2, max_features=log2, min_samples_leaf=8, min_samples_split=3, n_estimators=700, subsample=1.0;, score=-88838777.383 total time=   0.7s
# [CV 2/5] END learning_rate=0.018329807108324356, max_depth=2, max_features=log2, min_samples_leaf=8, min_samples_split=3, n_estimators=700, subsample=1.0;, score=-38345664.173 total time=   0.6s
# [CV 2/5] END learning_rate=0.3359818286283781, max_depth=18, max_features=None, min_samples_leaf=10, min_samples_split=8, n_estimators=400, subsample=0.5;, score=-92481139.448 total time=   1.9s
# [CV 1/5] END learning_rate=0.3359818286283781, max_depth=18, max_features=None, min_samples_leaf=10, min_samples_split=8, n_estimators=400, subsample=0.5;, score=-132027022.394 total time=   2.1s
# [CV 4/5] END learning_rate=0.3359818286283781, max_depth=18, max_features=None, min_samples_leaf=10, min_samples_split=8, n_estimators=400, subsample=0.5;, score=-169537341.224 total time=   1.9s
# [CV 5/5] END learning_rate=0.3359818286283781, max_depth=18, max_features=None, min_samples_leaf=10, min_samples_split=8, n_estimators=400, subsample=0.5;, score=-150276695.588 total time=   1.8s
# [CV 3/5] END learning_rate=0.3359818286283781, max_depth=18, max_features=None, min_samples_leaf=10, min_samples_split=8, n_estimators=400, subsample=0.5;, score=-74455416.905 total time=   1.9s
# [CV 3/5] END learning_rate=0.018329807108324356, max_depth=2, max_features=log2, min_samples_leaf=8, min_samples_split=3, n_estimators=700, subsample=1.0;, score=-53110777.277 total time=   0.6s
# [CV 4/5] END learning_rate=0.018329807108324356, max_depth=2, max_features=log2, min_samples_leaf=8, min_samples_split=3, n_estimators=700, subsample=1.0;, score=-91071116.900 total time=   0.6s
# [CV 5/5] END learning_rate=0.018329807108324356, max_depth=2, max_features=log2, min_samples_leaf=8, min_samples_split=3, n_estimators=700, subsample=1.0;, score=-133160699.223 total time=   0.6s
# [CV 1/5] END learning_rate=0.23357214690901212, max_depth=17, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=200, subsample=0.5;, score=-105150461.038 total time=   0.3s
# [CV 2/5] END learning_rate=0.23357214690901212, max_depth=17, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=200, subsample=0.5;, score=-74652163.332 total time=   0.3s
# [CV 3/5] END learning_rate=0.23357214690901212, max_depth=17, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=200, subsample=0.5;, score=-82431537.504 total time=   0.3s
# [CV 4/5] END learning_rate=0.23357214690901212, max_depth=17, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=200, subsample=0.5;, score=-102691933.118 total time=   0.3s
# [CV 1/5] END learning_rate=0.0379269019073225, max_depth=4, max_features=None, min_samples_leaf=6, min_samples_split=2, n_estimators=500, subsample=0.6;, score=-95070883.139 total time=   1.2s
# [CV 3/5] END learning_rate=0.0379269019073225, max_depth=4, max_features=None, min_samples_leaf=6, min_samples_split=2, n_estimators=500, subsample=0.6;, score=-43062039.280 total time=   1.2s
# [CV 1/5] END learning_rate=0.018329807108324356, max_depth=13, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=900, subsample=0.9;, score=-92472619.328 total time=   2.5s
# [CV 2/5] END learning_rate=0.0379269019073225, max_depth=4, max_features=None, min_samples_leaf=6, min_samples_split=2, n_estimators=500, subsample=0.6;, score=-47756840.973 total time=   1.2s
# [CV 4/5] END learning_rate=0.0379269019073225, max_depth=4, max_features=None, min_samples_leaf=6, min_samples_split=2, n_estimators=500, subsample=0.6;, score=-88565485.040 total time=   1.2s
# [CV 5/5] END learning_rate=0.23357214690901212, max_depth=17, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=200, subsample=0.5;, score=-145893616.210 total time=   0.3s
# [CV 2/5] END learning_rate=0.018329807108324356, max_depth=13, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=900, subsample=0.9;, score=-39291303.702 total time=   2.7s
# [CV 2/5] END learning_rate=0.23357214690901212, max_depth=16, max_features=sqrt, min_samples_leaf=10, min_samples_split=9, n_estimators=200, subsample=0.6;, score=-59231715.143 total time=   0.4s
# [CV 5/5] END learning_rate=0.0379269019073225, max_depth=4, max_features=None, min_samples_leaf=6, min_samples_split=2, n_estimators=500, subsample=0.6;, score=-122331763.582 total time=   1.4s
# [CV 3/5] END learning_rate=0.018329807108324356, max_depth=13, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=900, subsample=0.9;, score=-55016975.470 total time=   2.8s
# [CV 1/5] END learning_rate=0.23357214690901212, max_depth=16, max_features=sqrt, min_samples_leaf=10, min_samples_split=9, n_estimators=200, subsample=0.6;, score=-124098993.232 total time=   0.5s
# [CV 3/5] END learning_rate=0.23357214690901212, max_depth=16, max_features=sqrt, min_samples_leaf=10, min_samples_split=9, n_estimators=200, subsample=0.6;, score=-82684717.200 total time=   0.3s
# [CV 1/5] END learning_rate=0.6951927961775606, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=800, subsample=0.5;, score=-165763161.394 total time=   0.7s
# [CV 4/5] END learning_rate=0.018329807108324356, max_depth=13, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=900, subsample=0.9;, score=-76339160.803 total time=   2.9s
# [CV 5/5] END learning_rate=0.018329807108324356, max_depth=13, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=900, subsample=0.9;, score=-137378405.317 total time=   2.9s
# [CV 4/5] END learning_rate=0.6951927961775606, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=800, subsample=0.5;, score=-269200319.566 total time=   0.8s
# [CV 3/5] END learning_rate=0.6951927961775606, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=800, subsample=0.5;, score=-117580868.412 total time=   0.8s
# [CV 2/5] END learning_rate=0.6951927961775606, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=800, subsample=0.5;, score=-141101862.207 total time=   0.9s
# [CV 5/5] END learning_rate=0.23357214690901212, max_depth=16, max_features=sqrt, min_samples_leaf=10, min_samples_split=9, n_estimators=200, subsample=0.6;, score=-147252933.336 total time=   0.4s
# [CV 4/5] END learning_rate=0.23357214690901212, max_depth=16, max_features=sqrt, min_samples_leaf=10, min_samples_split=9, n_estimators=200, subsample=0.6;, score=-116516048.142 total time=   0.4s
# [CV 5/5] END learning_rate=0.6951927961775606, max_depth=4, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=800, subsample=0.5;, score=-169738181.960 total time=   1.0s
# [CV 1/5] END learning_rate=0.008858667904100823, max_depth=17, max_features=sqrt, min_samples_leaf=9, min_samples_split=3, n_estimators=300, subsample=0.7;, score=-80167400.382 total time=   0.6s
# [CV 1/5] END learning_rate=0.4832930238571752, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=200, subsample=0.5;, score=-93145484.259 total time=   0.2s
# [CV 3/5] END learning_rate=0.008858667904100823, max_depth=17, max_features=sqrt, min_samples_leaf=9, min_samples_split=3, n_estimators=300, subsample=0.7;, score=-48202788.855 total time=   0.5s
# [CV 2/5] END learning_rate=0.008858667904100823, max_depth=17, max_features=sqrt, min_samples_leaf=9, min_samples_split=3, n_estimators=300, subsample=0.7;, score=-38606788.234 total time=   0.6s
# [CV 2/5] END learning_rate=0.4832930238571752, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=200, subsample=0.5;, score=-94323664.345 total time=   0.2s
# [CV 5/5] END learning_rate=0.008858667904100823, max_depth=17, max_features=sqrt, min_samples_leaf=9, min_samples_split=3, n_estimators=300, subsample=0.7;, score=-131633560.469 total time=   0.6s
# [CV 3/5] END learning_rate=0.4832930238571752, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=200, subsample=0.5;, score=-70193478.863 total time=   0.2s
# [CV 5/5] END learning_rate=0.4832930238571752, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=200, subsample=0.5;, score=-150503341.761 total time=   0.2s
# [CV 4/5] END learning_rate=0.008858667904100823, max_depth=17, max_features=sqrt, min_samples_leaf=9, min_samples_split=3, n_estimators=300, subsample=0.7;, score=-60319752.883 total time=   0.7s
# [CV 4/5] END learning_rate=0.4832930238571752, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=200, subsample=0.5;, score=-187896861.044 total time=   0.2s
# [CV 2/5] END learning_rate=0.3359818286283781, max_depth=2, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=500, subsample=0.6;, score=-55223620.688 total time=   0.4s
# [CV 1/5] END learning_rate=0.3359818286283781, max_depth=2, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=500, subsample=0.6;, score=-83342093.494 total time=   0.5s
# [CV 2/5] END learning_rate=0.0379269019073225, max_depth=5, max_features=None, min_samples_leaf=9, min_samples_split=10, n_estimators=600, subsample=0.5;, score=-46913184.924 total time=   1.4s
# [CV 5/5] END learning_rate=0.0379269019073225, max_depth=5, max_features=None, min_samples_leaf=9, min_samples_split=10, n_estimators=600, subsample=0.5;, score=-132201933.284 total time=   1.3s
# [CV 3/5] END learning_rate=0.0379269019073225, max_depth=5, max_features=None, min_samples_leaf=9, min_samples_split=10, n_estimators=600, subsample=0.5;, score=-55892020.928 total time=   1.4s
# [CV 3/5] END learning_rate=0.3359818286283781, max_depth=2, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=500, subsample=0.6;, score=-62667784.295 total time=   0.4s
# [CV 4/5] END learning_rate=0.0379269019073225, max_depth=5, max_features=None, min_samples_leaf=9, min_samples_split=10, n_estimators=600, subsample=0.5;, score=-95507597.772 total time=   1.4s
# [CV 1/5] END learning_rate=0.0379269019073225, max_depth=5, max_features=None, min_samples_leaf=9, min_samples_split=10, n_estimators=600, subsample=0.5;, score=-102305664.528 total time=   1.6s
# [CV 4/5] END learning_rate=0.3359818286283781, max_depth=2, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=500, subsample=0.6;, score=-154162175.873 total time=   0.5s
# [CV 2/5] END learning_rate=0.23357214690901212, max_depth=3, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=700, subsample=0.6;, score=-37590402.052 total time=   1.3s
# [CV 5/5] END learning_rate=0.3359818286283781, max_depth=2, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=500, subsample=0.6;, score=-133527190.558 total time=   0.4s
# [CV 5/5] END learning_rate=0.23357214690901212, max_depth=3, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=700, subsample=0.6;, score=-143483930.437 total time=   1.2s
# [CV 3/5] END learning_rate=0.23357214690901212, max_depth=3, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=700, subsample=0.6;, score=-57240410.238 total time=   1.3s
# [CV 4/5] END learning_rate=0.23357214690901212, max_depth=3, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=700, subsample=0.6;, score=-89137629.749 total time=   1.3s
# [CV 1/5] END learning_rate=0.23357214690901212, max_depth=3, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=700, subsample=0.6;, score=-93576080.102 total time=   1.5s
# [CV 1/5] END learning_rate=0.002976351441631319, max_depth=18, max_features=None, min_samples_leaf=10, min_samples_split=4, n_estimators=100, subsample=0.9;, score=-101922366.748 total time=   0.5s
# [CV 2/5] END learning_rate=0.002976351441631319, max_depth=18, max_features=None, min_samples_leaf=10, min_samples_split=4, n_estimators=100, subsample=0.9;, score=-70407806.110 total time=   0.5s
# [CV 3/5] END learning_rate=0.002976351441631319, max_depth=18, max_features=None, min_samples_leaf=10, min_samples_split=4, n_estimators=100, subsample=0.9;, score=-66505412.165 total time=   0.5s
# [CV 4/5] END learning_rate=0.002976351441631319, max_depth=18, max_features=None, min_samples_leaf=10, min_samples_split=4, n_estimators=100, subsample=0.9;, score=-63221298.494 total time=   0.5s
# [CV 1/5] END learning_rate=0.6951927961775606, max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=800, subsample=0.6;, score=-120948327.030 total time=   0.9s
# [CV 2/5] END learning_rate=0.6951927961775606, max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=800, subsample=0.6;, score=-98132794.970 total time=   0.9s
# [CV 5/5] END learning_rate=0.002976351441631319, max_depth=18, max_features=None, min_samples_leaf=10, min_samples_split=4, n_estimators=100, subsample=0.9;, score=-167900724.263 total time=   0.5s
# [CV 5/5] END learning_rate=0.6951927961775606, max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=800, subsample=0.6;, score=-167214189.984 total time=   0.8s
# [CV 3/5] END learning_rate=0.6951927961775606, max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=800, subsample=0.6;, score=-113690897.527 total time=   0.9s
# [CV 4/5] END learning_rate=0.6951927961775606, max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=800, subsample=0.6;, score=-82057181.667 total time=   0.9s

# %%
excl = ['params', 'mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'split3_test_score', 'split4_test_score', 'std_test_score', 'rank_test_score']
for modelo in modelos:
    print(pd.DataFrame(results[modelo]).drop(excl, axis=1).sort_values('mean_test_score', ascending=False))
    print('\n\n')
# Out:
#    param_max_features param_max_depth param_criterion  mean_test_score
# 26               log2              39         poisson    -6.256190e+07
# 10               log2              21   squared_error    -6.307043e+07
# 80               log2               9  absolute_error    -6.321353e+07
# 65               sqrt              12   squared_error    -6.464448e+07
# 87               sqrt               9    friedman_mse    -6.633666e+07
# ..                ...             ...             ...              ...
# 11               log2               1  absolute_error    -8.382459e+07
# 34               sqrt               2         poisson    -8.406374e+07
# 8                sqrt              30         poisson    -8.422344e+07
# 52               sqrt               2   squared_error    -9.061333e+07
# 5                log2              28    friedman_mse    -9.498983e+07
#
# [100 rows x 4 columns]
#
#
#
#    param_n_neighbors param_metric  mean_test_score
# 9                  7           l1    -7.267404e+07
# 68                13           l1    -7.306498e+07
# 63                 9           l1    -7.307207e+07
# 32                16           l1    -7.329905e+07
# 84                13           l2    -7.398973e+07
# ..               ...          ...              ...
# 65                22       cosine    -1.076451e+08
# 86                20       cosine    -1.081832e+08
# 48                41       cosine    -1.086353e+08
# 71                18       cosine    -1.088884e+08
# 80                 7       cosine    -1.230875e+08
#
# [100 rows x 3 columns]
#
#
#
#    param_l1_ratio param_fit_intercept    param_alpha  mean_test_score
# 3        0.929293               False  141747.416293    -1.248254e+08
# 98       0.646465               False   22051.307399    -1.248479e+08
# 82       0.888889               False  141747.416293    -1.248650e+08
# 45       0.949495               False   359381.36638    -1.248800e+08
# 93       0.717172               False   22051.307399    -1.249225e+08
# ..            ...                 ...            ...              ...
# 90       0.575758                True            0.0    -1.309195e+08
# 97        0.10101                True            0.0    -1.309195e+08
# 64       0.363636                True            0.0    -1.309195e+08
# 48       0.979798                True            0.0    -1.309195e+08
# 99            1.0                True            0.0    -1.309195e+08
#
# [100 rows x 4 columns]
#
#
#
#    param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 31                400                       4                      1
# 85                400                       6                      1
# 75                800                       3                      1
# 6                 900                       8                      1
# 18                600                       9                      1
# ..                ...                     ...                    ...
# 90                300                       8                      8
# 64                700                       3                      7
# 4                 800                       3                      4
# 32                800                       2                      8
# 40                800                       7                      3
#
#    param_max_features param_max_depth param_bootstrap  mean_test_score
# 31               None              24            True    -5.713636e+07
# 85               None              43            True    -5.747516e+07
# 75               log2              29            True    -5.871303e+07
# 6                sqrt              26            True    -5.926190e+07
# 18               log2              16            True    -5.953186e+07
# ..                ...             ...             ...              ...
# 90               sqrt               3           False    -7.589641e+07
# 64               log2               2            True    -7.632361e+07
# 4                None               1            True    -8.229258e+07
# 32               log2               1           False    -8.790845e+07
# 40               log2               1           False    -9.609893e+07
#
# [100 rows x 7 columns]
#
#
#
#    param_subsample param_n_estimators param_min_samples_split  \
# 74             0.5                200                       5
# 76             0.8                600                       9
# 2              0.5                500                       3
# 51             0.9                200                       5
# 67             0.6                400                       3
# ..             ...                ...                     ...
# 85             0.5                400                       8
# 3              0.7                200                       7
# 91             0.5                800                       8
# 18             0.6                300                       8
# 28             0.7                100                       6
#
#    param_min_samples_leaf param_max_features param_max_depth  \
# 74                      1               sqrt               9
# 76                      2               None              15
# 2                       2               log2               7
# 51                      4               None               9
# 67                      3               sqrt              18
# ..                    ...                ...             ...
# 85                     10               None              18
# 3                       5               sqrt               7
# 91                      7               log2               4
# 18                      4               None               7
# 28                      5               sqrt              18
#
#    param_learning_rate  mean_test_score
# 74            0.012743    -6.068888e+07
# 76            0.004281    -6.610151e+07
# 2             0.008859    -6.693986e+07
# 51            0.008859    -6.732853e+07
# 67            0.008859    -6.885030e+07
# ..                 ...              ...
# 85            0.335982    -1.237555e+08
# 3                  1.0    -1.534233e+08
# 91            0.695193    -1.726769e+08
# 18                 1.0    -1.803034e+08
# 28                 1.0    -1.821359e+08
#
# [100 rows x 8 columns]

# %%
for modelo in results:
    print(modelo)
    print(max(results[modelo]['mean_test_score']))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# -62561901.902777076
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# -72674037.89193085
# <class 'sklearn.linear_model._coordinate_descent.ElasticNet'>
# -124825367.05760829
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# -57136360.68446754
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
# -60688879.09975741

# %%
# Usamos siempre el mismo conjunto de validacion (el ultimo 20%, porque permutamos los datos)
train_test_indices = [([i for i in range(320)], [i for i in range(320, 400)])]
fig, ax = plt.subplots(1, len(mejores), figsize=(20,4), sharey='row')
for i, modelo in enumerate(mejores):
    model_selection.LearningCurveDisplay.from_estimator(
        modelo, X_train, y_train, std_display_style=None, train_sizes = np.linspace(0.00001, 1, 20), scoring='neg_mean_absolute_error', cv=train_test_indices, ax=ax[i]
    )
    ax[i].set_title(modelo.__class__.__name__)
fig.suptitle('Curvas de aprendizaje')

plt.savefig('curvas_aprendizaje.png')
# Out:
# /home/godo/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 345, in _score
#     y_pred = method_caller(
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/utils/_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/neighbors/_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 1, n_samples = 80
#
#   warnings.warn(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 345, in _score
#     y_pred = method_caller(
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 87, in _cached_call
#     result, _ = _get_response_values(
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/utils/_response.py", line 238, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/neighbors/_regression.py", line 242, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 835, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 1, n_samples = 1
#
#   warnings.warn(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.804e+14, tolerance: 4.135e+12
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.514e+16, tolerance: 8.415e+14
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.305e+16, tolerance: 8.587e+14
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.463e+16, tolerance: 9.494e+14
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.596e+16, tolerance: 9.608e+14
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.123e+16, tolerance: 9.639e+14
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.085e+17, tolerance: 3.786e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.242e+17, tolerance: 3.815e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.307e+17, tolerance: 3.819e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.358e+17, tolerance: 3.822e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.016e+17, tolerance: 4.029e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.117e+17, tolerance: 4.035e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.253e+17, tolerance: 4.037e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.457e+17, tolerance: 4.050e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.513e+17, tolerance: 4.053e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.610e+17, tolerance: 4.057e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.879e+17, tolerance: 4.072e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.008e+17, tolerance: 4.087e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.083e+17, tolerance: 4.163e+15
#   model = cd_fast.enet_coordinate_descent(
# /home/godo/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:547: FitFailedWarning:
# 1 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/ensemble/_gb.py", line 784, in fit
#     n_stages = self._fit_stages(
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/ensemble/_gb.py", line 873, in _fit_stages
#     initial_loss = factor * self._loss(
#   File "/home/godo/.local/lib/python3.10/site-packages/sklearn/_loss/loss.py", line 399, in __call__
#     return np.average(
#   File "/home/godo/.local/lib/python3.10/site-packages/numpy/lib/function_base.py", line 550, in average
#     raise ZeroDivisionError(
# ZeroDivisionError: Weights sum to zero, can't be normalized
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
df['PredReclamo'] = mejores[3].predict(X)
df['DifReclamo'] = df['PredReclamo']/df['ValorReclamo']
df.loc[df['DifReclamo'] > 50, [*features, 'geometry', 'DifReclamo', 'PredReclamo', 'ValorReclamo']].explore('DifReclamo')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd6d84b03aedc18c72b74ad286cffc12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd6d84b03aedc18c72b74ad286cffc12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd6d84b03aedc18c72b74ad286cffc12 = L.map(
#                 &quot;map_dd6d84b03aedc18c72b74ad286cffc12&quot;,
#                 {
#                     center: [-31.44172855532318, -64.57421816212187],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_dd6d84b03aedc18c72b74ad286cffc12);
#
#
#
#
#
#             var tile_layer_8555813677134455c6b692c111d4f74f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8555813677134455c6b692c111d4f74f.addTo(map_dd6d84b03aedc18c72b74ad286cffc12);
#
#
#             map_dd6d84b03aedc18c72b74ad286cffc12.fitBounds(
#                 [[-31.563534741378785, -64.70115473552308], [-31.319922369267573, -64.44728158872066]],
#                 {}
#             );
#
#
#         function geo_json_68d7c3c0a54b590646702244a86b71d7_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;22&quot;: case &quot;43&quot;: case &quot;50&quot;: case &quot;64&quot;: case &quot;67&quot;:
#                     return {&quot;color&quot;: &quot;#46085c&quot;, &quot;fillColor&quot;: &quot;#46085c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;2&quot;: case &quot;4&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;42&quot;: case &quot;44&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;59&quot;: case &quot;61&quot;: case &quot;68&quot;: case &quot;72&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#460a5d&quot;, &quot;fillColor&quot;: &quot;#460a5d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;34&quot;: case &quot;49&quot;:
#                     return {&quot;color&quot;: &quot;#46075a&quot;, &quot;fillColor&quot;: &quot;#46075a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#471365&quot;, &quot;fillColor&quot;: &quot;#471365&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;21&quot;: case &quot;36&quot;: case &quot;39&quot;: case &quot;47&quot;: case &quot;51&quot;: case &quot;57&quot;: case &quot;65&quot;: case &quot;66&quot;:
#                     return {&quot;color&quot;: &quot;#450457&quot;, &quot;fillColor&quot;: &quot;#450457&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;13&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;31&quot;: case &quot;37&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;58&quot;: case &quot;69&quot;: case &quot;70&quot;:
#                     return {&quot;color&quot;: &quot;#440256&quot;, &quot;fillColor&quot;: &quot;#440256&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#470d60&quot;, &quot;fillColor&quot;: &quot;#470d60&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#460b5e&quot;, &quot;fillColor&quot;: &quot;#460b5e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;23&quot;: case &quot;71&quot;:

# %% [markdown]
# # Exportar

# %%
pd.DataFrame({'Valuacion_Danios': mejores[3].predict(df[features])}, index=df.index).to_csv('pred.csv')
# Out:
# /home/godo/.local/lib/python3.10/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
#                    Valuacion_Danios
# idParcela
# 2519551-SAN ROQUE      1.708955e+07
# 2449020-SANTIAGO       1.448572e+07
# 2448933-SAN ROQUE      3.285977e+07
# 1205390-SANTIAGO       3.009105e+07
# 1141971-SAN ROQUE      2.015707e+05
# ...                             ...
# 1204495-SAN ROQUE      1.396246e+07
# 1136506-SAN ROQUE      4.512910e+07
# 1173094-SAN ROQUE      1.137569e+07
# 1181494-SAN ROQUE      5.745038e+07
# 1199878-SANTIAGO       3.346558e+08
#
# [1047 rows x 1 columns]
